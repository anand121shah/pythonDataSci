# %%
import csv
import os

import pandas as pd

# %%
df = pd.read_csv('/content/june6.csv', encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-0c5a29634ff2> in <cell line: 1>()
# ----> 1 df = pd.read_csv('/content/june6.csv', encoding='latin-1')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df

# %%
df.iat[1][2]

# %%
len(df.columns)

for i in (0, 13):
  count = 0
  for j in df.columns[i]:
    if ((df.iat[i][j]).isna()):
      count+=1
  print('NaN in ', df.columns[i], '=', count)

# %%
num_columns = len(df.columns)

for i in range(num_columns):
    column_name = df.columns[i]
    count = df[column_name].isna().sum()
    print('NaN in', column_name, '=', count)

# %%
df.columns[1]

# %%
df_0 = df.fillna(0)

# %%
df

# %%
df_mean = df.fillna(df.mean())

# %%
df_mean = df_mean.fillna(0)

# %%
df_mean['DIRECTOR_facebook_likes'] = df_mean['DIRECTOR_facebook_likes'].astype(float)

# %%
df_mean

# %%
 import matplotlib.pyplot as plt

# Sample data
x = df.column[1]
y = df.column[2]

# Create scatter plot
plt.scatter(x, y)

# Set labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')

# Show the plot
plt.show()
