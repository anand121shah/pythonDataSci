# %% [markdown]
# <a href="https://colab.research.google.com/github/as-bestinclass/pythonDataSci/blob/main/Introduction_to_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("drive/My Drive/Hotel_Reviews.csv")

# %%
df.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# ...

# %%
df_selected=df[['Hotel_Address','Negative_Review','Positive_Review','Reviewer_Score']]

# %%
df_selected.head(2)
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#                                      Negative_Review  \
# 0   I am so angry that i made this post available...
# 1                                        No Negative
#
#                                      Positive_Review  Reviewer_Score
# 0   Only the park outside of the hotel was beauti...             2.9
# 1   No real complaints the hotel was great great ...             7.5

# %%
# Bringing all the words to same case (mostly lower case)
# removing unwanted characters # Remove punctuations
# Tokenization (optional) "I am so angry that i made this post" change to ["I", "am", "so" ,"angry", "that", "i", "made", "this", "post"]
# remove useless stop words like 'the', 'a' ,'this' etc.
# Stemming or lemitization transform every word into their root form (e.g. rooms -> room, slept -> sleep)

# %%
# TWO PARTS OF EMBEDDINGS OR NUMERICAL REPRESENTATION
#1) TFIDF,COUNT VECTORIZERS such static models dont need tokenization
#2) Models like bert,Doc2Vec need # Tokenization and removing unwanted characters

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
def clean_text(sentence):

  # Converting all words to lower
  sentence_lowered=sentence.lower()
  # fetched words from nltk package
  stop = stopwords.words('english')

  stop_words_removed_sentence=[]
  for k in sentence_lowered.split(" "):
    if k not in stop:
      stop_words_removed_sentence.append(lemmatizer.lemmatize(k))
  stop_words_removed_sentence=" ".join(stop_words_removed_sentence)
  print(stop_words_removed_sentence)

# %%
text_sample="I am so angry that i made this post available"
clean_text(text_sample)
# Out:
# angry made post available

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# !pip install -U sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 90.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 59.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.2 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=3373443fa6b1fd0c6197118f4b369be6f6b857e0ee9b60a22fc22342440cf213
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...

# %%
from sentence_transformers import SentenceTransformer
# BERT covered for 100 languages different models you can read about them

model = SentenceTransformer('all-MiniLM-L6-v2')
sentences = ['This framework generates embeddings for each input sentence',
    'Sentences are passed as a list of string.',
    'The quick brown fox jumps over the lazy dog.']

#Sentences are encoded by calling model.encode()
embeddings = model.encode(sentences)

#Print the embeddings
for sentence, embedding in zip(sentences, embeddings):
    print("Sentence:", sentence)
    print("Embedding:", embedding.shape)
    print("")
# Out:
# Sentence: This framework generates embeddings for each input sentence
# Embedding: (384,)
#
# Sentence: Sentences are passed as a list of string.
# Embedding: (384,)
#
# Sentence: The quick brown fox jumps over the lazy dog.
# Embedding: (384,)

# %%
"""
deep learning model made by google based on encoder-decoder architechture
# 1 encoder we decrease the neurons
512
256
64
32

64
256
512
"""

# %% [markdown]
# 3 models using random forest or any algorithm
#
# 1) TFIDF and label   to do classification
#
# 2) With Count vectorizer to do classification
#
# 3) With Feature engineering like we did
# 3 a) number of words in total, Number of words in negative review, Number of words in positive review,total reviews for each property and then add compound value from SentimentIntensityanalyser for both negative review and positive review separately
# pass these to model with label and do classification
#
# ONCE THESE ARE DONE
#
# 4) Use Sentence Transformer for classification using randomForest
#
# 5) use clean_text function or preprocessing we discussed create TF-IDF and pass to randomforest  to compare results
